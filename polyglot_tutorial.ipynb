# %% [markdown]
# # NLP with polyglot

# %%
from __future__ import print_function
import polyglot
from polyglot.text import Text, Word

# %% [markdown]
# ## Language detection

# %%
text = Text("Bonjour, Mesdames.")
print("Language Detected: Code={}, Name={}\n".format(text.language.code, text.language.name))
# Out:
# Language Detected: Code=fr, Name=French

# %% [markdown]
# The language detection is a cached field of the text object which is lazily populated. The detection can be called explicitely (it depends on the library pycld2):

# %%
from polyglot.detect import Detector

# %%
arabic_text = u"""
أفاد مصدر امني في قيادة عمليات صلاح الدين في العراق بأن " القوات الامنية تتوقف لليوم
الثالث على التوالي عن التقدم الى داخل مدينة تكريت بسبب
انتشار قناصي التنظيم الذي يطلق على نفسه اسم "الدولة الاسلامية" والعبوات الناسفة
والمنازل المفخخة والانتحاريين، فضلا عن ان القوات الامنية تنتظر وصول تعزيزات اضافية ".
"""

# %%
detector = Detector(arabic_text)
print(detector.language)
# Out:
# name: Arabic      code: ar       confidence:  99.0 read bytes:   907

# %% [markdown]
# ### Language detection for multilinguagel mixted texts

# %%
mixed_text = u"""
China (simplified Chinese: 中国; traditional Chinese: 中國),
officially the People's Republic of China (PRC), is a sovereign state located in East Asia.
"""

# %%
for language in Detector(mixed_text).languages:
      print(language)
# Out:
# name: English     code: en       confidence:  87.0 read bytes:  1154
# name: Chinese     code: zh_Hant  confidence:   5.0 read bytes:  1755
# name: un          code: un       confidence:   0.0 read bytes:     0

# %%
for line in mixed_text.strip().splitlines():
    print(line + u"\n")
    for language in Detector(line).languages:
        print(language)
# Out:
# China (simplified Chinese: 中国; traditional Chinese: 中國),
#
# name: English     code: en       confidence:  71.0 read bytes:   887
# name: Chinese     code: zh_Hant  confidence:  11.0 read bytes:  1755
# name: un          code: un       confidence:   0.0 read bytes:     0
# officially the People's Republic of China (PRC), is a sovereign state located in East Asia.
#
# name: English     code: en       confidence:  98.0 read bytes:  1291
# name: un          code: un       confidence:   0.0 read bytes:     0
# name: un          code: un       confidence:   0.0 read bytes:     0

# %% [markdown]
# ### Best effort strategy for short texts

# %%
print(Detector("pizza"))
# Out:
# WARNING:polyglot.detect.base:Detector is not able to detect the language reliably.
# Prediction is reliable: False
# Language 1: name: English     code: en       confidence:  85.0 read bytes:  1194
# Language 2: name: un          code: un       confidence:   0.0 read bytes:     0
# Language 3: name: un          code: un       confidence:   0.0 read bytes:     0

# %%
# When the text is too short, an exception is thrown!
try:
    print(Detector("4"))
except Exception as e:
    print(e)
# Out:
# Try passing a longer snippet of text

# %% [markdown]
# ## POS Tagging

# %%
from polyglot.downloader import downloader
print(downloader.supported_languages_table("pos2"))
# Out:
#   1. German                     2. Italian                    3. Danish
#   4. Czech                      5. Slovene                    6. French
#   7. English                    8. Finnish                    9. Bulgarian
#  10. Spanish; Castilian        11. Swedish                   12. Portuguese
#  13. Indonesian                14. Irish                     15. Hungarian
#  16. Dutch

# %% [markdown]
# ### English

# %%
# %%bash
# polyglot download embeddings2.en pos2.en
# Out:
# [polyglot_data] Downloading package embeddings2.en to
# [polyglot_data]     /home/pgross/polyglot_data...
# [polyglot_data]   Package embeddings2.en is already up-to-date!
# [polyglot_data] Downloading package pos2.en to
# [polyglot_data]     /home/pgross/polyglot_data...
# [polyglot_data]   Package pos2.en is already up-to-date!

# %%
text_en = Text(u"""
Police Academy star George Gaynes dies at 98
5 hours ago
 From the section Entertainment & Arts
George GaynesImage copyrightRex Features
Image caption
George Gaynes starred in 35 films over the course of his career
The actor George Gaynes died on Monday, at the age of 98, his daughter confirmed.
Gaynes starred in all seven Police Academy movies and had a lead role in the 1980s sitcom Punky Brewster.
He also performed alongside Dustin Hoffman in the Oscar-nominated film, Tootsie.
His longtime agent, Jonathan Howard, told The Hollywood Reporter that his death was "a sad, sad loss. But he had a really long, great life."
""")
text_en.pos_tags
# Out:
# [(u'Police', u'PROPN'),
#  (u'Academy', u'NOUN'),
#  (u'star', u'NOUN'),
#  (u'George', u'PROPN'),
#  (u'Gaynes', u'PROPN'),
#  (u'dies', u'VERB'),
#  (u'at', u'ADP'),
#  (u'98', u'NUM'),
#  (u'5', u'NUM'),
#  (u'hours', u'NOUN'),
#  (u'ago', u'ADV'),
#  (u'From', u'ADP'),
#  (u'the', u'DET'),
#  (u'section', u'NOUN'),
#  (u'Entertainment', u'NOUN'),
#  (u'&', u'CONJ'),
#  (u'Arts', u'PROPN'),
#  (u'George', u'PROPN'),
#  (u'GaynesImage', u'PUNCT'),
#  (u'copyrightRex', u'NUM'),
#  (u'Features', u'PROPN'),
#  (u'Image', u'NOUN'),
#  (u'caption', u'NOUN'),
#  (u'George', u'PROPN'),
#  (u'Gaynes', u'NUM'),
#  (u'starred', u'VERB'),
#  (u'in', u'ADP'),
#  (u'35', u'NUM'),
#  (u'films', u'NOUN'),
#  (u'over', u'ADP'),
#  (u'the', u'DET'),
#  (u'course', u'NOUN'),
#  (u'of', u'ADP'),
#  (u'his', u'PRON'),
#  (u'career', u'NOUN'),
#  (u'The', u'DET'),
#  (u'actor', u'NOUN'),
#  (u'George', u'PROPN'),
#  (u'Gaynes', u'PROPN'),
#  (u'died', u'VERB'),
#  (u'on', u'ADP'),
#  (u'Monday', u'PROPN'),
#  (u',', u'PUNCT'),
#  (u'at', u'ADP'),
#  (u'the', u'DET'),
#  (u'age', u'NOUN'),
#  (u'of', u'ADP'),
#  (u'98', u'NUM'),
#  (u',', u'PUNCT'),
#  (u'his', u'PRON'),
#  (u'daughter', u'NOUN'),
#  (u'confirmed', u'VERB'),
#  (u'.', u'PUNCT'),
#  (u'Gaynes', u'NUM'),
#  (u'starred', u'VERB'),
#  (u'in', u'ADP'),
#  (u'all', u'DET'),
#  (u'seven', u'NUM'),
#  (u'Police', u'PROPN'),
#  (u'Academy', u'PROPN'),
#  (u'movies', u'NOUN'),
#  (u'and', u'CONJ'),
#  (u'had', u'VERB'),
#  (u'a', u'DET'),
#  (u'lead', u'NOUN'),
#  (u'role', u'NOUN'),
#  (u'in', u'ADP'),
#  (u'the', u'DET'),
#  (u'1980s', u'ADJ'),
#  (u'sitcom', u'NOUN'),
#  (u'Punky', u'PUNCT'),
#  (u'Brewster', u'PROPN'),
#  (u'.', u'PUNCT'),
#  (u'He', u'PRON'),
#  (u'also', u'ADV'),
#  (u'performed', u'VERB'),
#  (u'alongside', u'ADP'),
#  (u'Dustin', u'PROPN'),
#  (u'Hoffman', u'PROPN'),
#  (u'in', u'ADP'),
#  (u'the', u'DET'),
#  (u'Oscar', u'PROPN'),
#  (u'-', u'PUNCT'),
#  (u'nominated', u'VERB'),
#  (u'film', u'NOUN'),
#  (u',', u'PUNCT'),
#  (u'Tootsie', u'PROPN'),
#  (u'.', u'PUNCT'),
#  (u'His', u'PRON'),
#  (u'longtime', u'ADJ'),
#  (u'agent', u'NOUN'),
#  (u',', u'PUNCT'),
#  (u'Jonathan', u'PROPN'),
#  (u'Howard', u'PROPN'),
#  (u',', u'PUNCT'),
#  (u'told', u'VERB'),
#  (u'The', u'DET'),
#  (u'Hollywood', u'PROPN'),
#  (u'Reporter', u'NOUN'),
#  (u'that', u'SCONJ'),
#  (u'his', u'PRON'),
#  (u'death', u'NOUN'),
#  (u'was', u'VERB'),
#  (u'"', u'PUNCT'),
#  (u'a', u'DET'),
#  (u'sad', u'ADJ'),
#  (u',', u'PUNCT'),
#  (u'sad', u'ADJ'),
#  (u'loss', u'NOUN'),
#  (u'.', u'PUNCT'),
#  (u'But', u'CONJ'),
#  (u'he', u'PRON'),
#  (u'had', u'VERB'),
#  (u'a', u'DET'),
#  (u'really', u'ADV'),
#  (u'long', u'ADV'),
#  (u',', u'PUNCT'),
#  (u'great', u'ADJ'),
#  (u'life', u'NOUN'),
#  (u'.', u'PUNCT'),
#  (u'"', u'PUNCT')]

# %% [markdown]
# ## German

# %%
# %%bash
# polyglot download embeddings2.de pos2.de
# Out:
# [polyglot_data] Downloading package embeddings2.de to
# [polyglot_data]     /home/pgross/polyglot_data...
# [polyglot_data]   Package embeddings2.de is already up-to-date!
# [polyglot_data] Downloading package pos2.de to
# [polyglot_data]     /home/pgross/polyglot_data...
# [polyglot_data]   Package pos2.de is already up-to-date!

# %%
text_de = Text(u"""
Flüchtlinge in Serbien

Das letzte Land ohne Zäune
Von Keno Verseck

Die Nachbarländer schotten ihre Grenzen ab, nun landen in Serbien immer mehr Flüchtlinge. Die bisherige, freizügige Politik erweist sich als Falle für das Land. Gleichzeitig boomt das Geschäft der Schlepper.

Serbien dürfe kein "Parkplatz für Flüchtlinge" werden, kein "Sammellager für Migranten auf dem Balkan" - solche drastischen Worte sind derzeit in Belgrad vom serbischen Regierungschef Aleksandar Vucic oder von Mitgliedern seines Kabinetts immer öfter zu hören.

Aus gutem Grund, denn in Serbien könnte genau das eintreten, wovor die Regierung warnt: Im größten Land des Westbalkans stranden immer mehr Flüchtlinge - sie sind von Süden her legal oder illegal eingereist, wollen weiterziehen nach Westeuropa, stoßen aber im Norden auf abgesperrte Grenzen oder werden aus den Nachbarländern abgeschoben.

Noch geht es nach Schätzungen von Beobachtern nur um höchstens einige Tausend Menschen, die vor allem in Belgrad und in der nordserbischen Wojwodina an der Grenze zu Ungarn umherirren und eine Gelegenheit zur illegalen Weiterreise suchen. Doch die Zahl könnte sich bald vervielfachen.

"Serbien ist eingequetscht zwischen Abschottung im Norden und dem Strom der Flüchtlinge von Süden", sagt Rados Djurovic, der Direktor des Belgrader "Zentrums zum Schutz für Asylsuchende" (CZA). Und die Politologin Jelena Milic vom Belgrader "Zentrum für euro-atlantische Studien" (CEAS) prognostiziert ein "Desaster für Serbien, wenn Österreich, Slowenien und Kroatien dichtmachen".

Serbien ist bisher, abgesehen von Griechenland, der einzige Staat auf der Balkanroute für Flüchtlinge, der noch keine Grenzzäune gebaut oder seine Grenze nicht zumindest mit Polizei und Militär stark abgeschirmt hat.

Das war ein Kalkül des nationalistisch-autoritären Regierungschefs Vucic, der sich vor einigen Jahren plötzlich vom überzeugten Kriegshetzer zum vorgeblichen Pro-Europäer wandelte und der in der Flüchtlingskrise als einziger Regierungschef der Region explizit immer wieder die Linie Angela Merkels unterstützte.

Vucic setzt auf Annäherung

Vucic betonte wiederholt, Zäune und Abschottung seien keine Lösung - er hoffte darauf, dass er mit dieser Linie Serbiens Annährung an die EU beschleunigen könnte und dass westliche Politiker die politischen Verhältnisse in Serbien weniger kritisch beäugen würden: Ein Großteil der politischen Elite ist in Korruption und organisiertes Verbrechen verstrickt, die Justiz vielfach politisch gelenkt, es gibt nur wenige unabhängige Medien, und unabhängige Journalisten leben gefährlich.

Zugleich ist Serbien wegen der prekären wirtschaftlichen und sozialen Verhältnisse im Land dringend auf eine europäische Integration, auf Investitionen und auf finanzielle Entwicklungshilfe durch die EU angewiesen.

Vucics Rechnung schien aufzugehen - Ende letzten Jahres eröffneten die EU und Serbien die ersten beiden Kapitel der Beitrittsverhandlungen, weitere sollen demnächst folgen. Doch Jelena Milic sagt, dass die serbische Flüchtlingspolitik sich als Falle für das Land erweisen könnte. Denn die Nachbarstaaten schaffen weiter Fakten:

Ungarn hat seine Grenze zu Serbien bereits seit September letzten Jahres vollständig mit einem Zaun abgeriegelt. Seit Anfang Januar ist die Zahl der illegalen Grenzübertritte aus Serbien wieder deutlich angestiegen, deshalb verdoppelte Ungarn die Zahl der Polizisten, die das Grenzgebiet bewachen.
Österreich hat mit seiner zunehmend restriktiveren Flüchtlingspolitik auf der Balkanroute einen Dominoeffekt ausgelöst, jede neue Beschränkung im Alpenland wird nach Süden hin weitergegeben; aktuell ist dies nach der österreichischen Ankündigung, nur noch eine stark begrenzte Anzahl von Flüchtlingen einreisen zu lassen, der Fall.
Zugleich mit Österreich baute auch Slowenien Grenzzäune und sicherte seine Grenze mit Sondertruppen der Polizei und der Armee.
Kroatien erwägt ebenfalls einen Zaunbau und lässt seine Grenze zu Serbien massiv durch polizeiliche Sondereinheiten bewachen. Ein Aufnahmelager für Flüchtlinge im ostkroatischen Slavonski Brod soll geschlossen werden, Kroatien will Flüchtlingen nur noch einen Non-Stop-Transit durch das Land erlauben.
Mazedonien und Bulgarien sollen nach den Vorstellungen der Visegrád-Länder Polen, Tschechien, Slowakei und Ungarn sowie Österreichs und Sloweniens zu Frontstaaten gegen Flüchtlinge aufgerüstet werden, falls Griechenland den Flüchtlingsstrom nicht stoppt. Beide Länder bauen derzeit ihre Grenzzäune zu Griechenland und der Türkei aus; Mazedonien lässt seit Längerem nur noch Flüchtlinge aus Afghanistan, Irak und Syrien mit gültigen Papieren durchreisen.
Mittendrin liegt Serbien - praktisch kaum geschützt. Erstmals wurde in dieser Woche eine größere Gruppe von Flüchtlingen durch mehrere Länder der Balkanroute nach Serbien zurückgereicht: 217 Menschen, die meisten von ihnen Afghanen, wurden von Slowenien nach Kroatien und von dort aus wiederum nach Serbien abgeschoben. Serbische Behörden sind ratlos, was sie mit ihnen machen sollen - Mazedonien will sie vorerst nicht zurücknehmen, vermutlich würden sie irgendwann in ihre Herkunftsländer ausgeflogen, sagt die Sprecherin des Innenministeriums, Biljana Popovic.

Neuer Markt für Schlepper

Die Abschottungspolitik in Serbiens Nachbarländern hat auch zur Folge, dass immer mehr kriminelle Schlepper in serbischen Grenzgebieten aktiv sind, wie Rados Djurovic vom "Zentrum zum Schutz für Asylsuchende" sagt. "Die Leute, die nicht mehr durchgelassen werden, sind die perfekte Beute für Schlepper", so Djurovic. Vor allem an der Grenze zu Mazedonien und zu Ungarn blühe das Schlepperunwesen momentan wieder auf.

Noch ist unklar, wann und wie Serbien seine Flüchtlingspolitik ändern wird. Das Land ist besonders wegen Kosovo in einer schwierige Lage: Selbst wenn es seine Grenzen zu Bulgarien und Mazedonien schließt, bliebe die zu Kosovo offen, da Serbien das Land nicht anerkennt, sondern als abtrünnige Provinz betrachtet.

Doch dass bald eine Änderung in der Flüchtlingspolitik anstehen könnte, daran lässt die serbische Regierung keinen Zweifel. "Ich bin kein Freund von Mauern", sagte Regierungschef Aleksandar Vucic kürzlich, "aber wir müssen unsere Grenzen schützen." Sein Außenminister Ivica Dacic ging dieser Tage noch weiter: "Wir werden es nicht zulassen, dass die Flüchtlinge in Serbien bleiben. Wenn alle anderen die Grenzen schließen, machen wir es auch."

Zusammengefasst: Immer mehr Flüchtlinge stranden in Serbien - weil viele Nachbarländer Zäune hochziehen. Und das Land fürchtet Tausende weitere Ankömmlinge. Und auch die Schlepper operieren in immer größerem Stil von serbischem Gebiet aus. Die Frage ist: Wie lange kann sich das Land noch eine liberale Flüchtlingspolitik leisten?
""")

# %%
text_de.pos_tags
# Out:
# [(u'Fl\xfcchtlinge', u'NOUN'),
#  (u'in', u'ADP'),
#  (u'Serbien', u'PROPN'),
#  (u'Das', u'DET'),
#  (u'letzte', u'ADJ'),
#  (u'Land', u'NOUN'),
#  (u'ohne', u'ADP'),
#  (u'Z\xe4une', u'NOUN'),
#  (u'Von', u'PROPN'),
#  (u'Keno', u'PROPN'),
#  (u'Verseck', u'NOUN'),
#  (u'Die', u'DET'),
#  (u'Nachbarl\xe4nder', u'NOUN'),
#  (u'schotten', u'PROPN'),
#  (u'ihre', u'DET'),
#  (u'Grenzen', u'NOUN'),
#  (u'ab', u'ADP'),
#  (u',', u'PUNCT'),
#  (u'nun', u'ADV'),
#  (u'landen', u'VERB'),
#  (u'in', u'ADP'),
#  (u'Serbien', u'PROPN'),
#  (u'immer', u'ADV'),
#  (u'mehr', u'ADV'),
#  (u'Fl\xfcchtlinge', u'NOUN'),
#  (u'.', u'PUNCT'),
#  (u'Die', u'DET'),
#  (u'bisherige', u'NOUN'),
#  (u',', u'PUNCT'),
#  (u'freiz\xfcgige', u'PROPN'),
#  (u'Politik', u'NOUN'),
#  (u'erweist', u'VERB'),
#  (u'sich', u'PRON'),
#  (u'als', u'ADP'),
#  (u'Falle', u'NOUN'),
#  (u'f\xfcr', u'ADP'),
#  (u'das', u'DET'),
#  (u'Land', u'NOUN'),
#  (u'.', u'PUNCT'),
#  (u'Gleichzeitig', u'ADV'),
#  (u'boomt', u'PROPN'),
#  (u'das', u'DET'),
#  (u'Gesch\xe4ft', u'NOUN'),
#  (u'der', u'DET'),
#  (u'Schlepper', u'NOUN'),
#  (u'.', u'PUNCT'),
#  (u'Serbien', u'PROPN'),
#  (u'd\xfcrfe', u'AUX'),
#  (u'kein', u'PRON'),
#  (u'"', u'PUNCT'),
#  (u'Parkplatz', u'NOUN'),
#  (u'f\xfcr', u'PROPN'),
#  (u'Fl\xfcchtlinge', u'NOUN'),
#  (u'"', u'PUNCT'),
#  (u'werden', u'AUX'),
#  (u',', u'PUNCT'),
#  (u'kein', u'ADV'),
#  (u'"', u'PUNCT'),
#  (u'Sammellager', u'NOUN'),
#  (u'f\xfcr', u'ADP'),
#  (u'Migranten', u'NOUN'),
#  (u'auf', u'ADP'),
#  (u'dem', u'DET'),
#  (u'Balkan', u'PROPN'),
#  (u'"', u'PUNCT'),
#  (u'-', u'PUNCT'),
#  (u'solche', u'PRON'),
#  (u'drastischen', u'ADJ'),
#  (u'Worte', u'NOUN'),
#  (u'sind', u'AUX'),
#  (u'derzeit', u'ADV'),
#  (u'in', u'ADP'),
#  (u'Belgrad', u'PROPN'),
#  (u'vom', u'DET'),
#  (u'serbischen', u'ADJ'),
#  (u'Regierungschef', u'NOUN'),
#  (u'Aleksandar', u'PROPN'),
#  (u'Vucic', u'PROPN'),
#  (u'oder', u'CONJ'),
#  (u'von', u'ADP'),
#  (u'Mitgliedern', u'NOUN'),
#  (u'seines', u'DET'),
#  (u'Kabinetts', u'NOUN'),
#  (u'immer', u'ADV'),
#  (u'\xf6fter', u'ADV'),
#  (u'zu', u'PART'),
#  (u'h\xf6ren', u'VERB'),
#  (u'.', u'PUNCT'),
#  (u'Aus', u'ADP'),
#  (u'gutem', u'ADJ'),
#  (u'Grund', u'NOUN'),
#  (u',', u'PUNCT'),
#  (u'denn', u'CONJ'),
#  (u'in', u'ADP'),
#  (u'Serbien', u'PROPN'),
#  (u'k\xf6nnte', u'AUX'),
#  (u'genau', u'ADV'),
#  (u'das', u'PRON'),
#  (u'eintreten', u'VERB'),
#  (u',', u'PUNCT'),
#  (u'wovor', u'NOUN'),
#  (u'die', u'DET'),
#  (u'Regierung', u'NOUN'),
#  (u'warnt', u'VERB'),
#  (u':', u'PUNCT'),
#  (u'Im', u'DET'),
#  (u'gr\xf6\xdften', u'ADJ'),
#  (u'Land', u'NOUN'),
#  (u'des', u'DET'),
#  (u'Westbalkans', u'PROPN'),
#  (u'stranden', u'X'),
#  (u'immer', u'ADV'),
#  (u'mehr', u'PRON'),
#  (u'Fl\xfcchtlinge', u'NOUN'),
#  (u'-', u'PUNCT'),
#  (u'sie', u'PRON'),
#  (u'sind', u'VERB'),
#  (u'von', u'ADP'),
#  (u'S\xfcden', u'NOUN'),
#  (u'her', u'PROPN'),
#  (u'legal', u'ADJ'),
#  (u'oder', u'CONJ'),
#  (u'illegal', u'ADJ'),
#  (u'eingereist', u'NOUN'),
#  (u',', u'PUNCT'),
#  (u'wollen', u'PRON'),
#  (u'weiterziehen', u'PROPN'),
#  (u'nach', u'ADP'),
#  (u'Westeuropa', u'PROPN'),
#  (u',', u'PUNCT'),
#  (u'sto\xdfen', u'VERB'),
#  (u'aber', u'ADV'),
#  (u'im', u'ADP'),
#  (u'Norden', u'NOUN'),
#  (u'auf', u'ADP'),
#  (u'abgesperrte', u'ADJ'),
#  (u'Grenzen', u'NOUN'),
#  (u'oder', u'CONJ'),
#  (u'werden', u'AUX'),
#  (u'aus', u'ADP'),
#  (u'den', u'DET'),
#  (u'Nachbarl\xe4ndern', u'NOUN'),
#  (u'abgeschoben', u'VERB'),
#  (u'.', u'PUNCT'),
#  (u'Noch', u'ADV'),
#  (u'geht', u'VERB'),
#  (u'es', u'PRON'),
#  (u'nach', u'ADP'),
#  (u'Sch\xe4tzungen', u'NOUN'),
#  (u'von', u'ADP'),
#  (u'Beobachtern', u'NOUN'),
#  (u'nur', u'ADV'),
#  (u'um', u'ADP'),
#  (u'h\xf6chstens', u'ADV'),
#  (u'einige', u'PRON'),
#  (u'Tausend', u'NUM'),
#  (u'Menschen', u'NOUN'),
#  (u',', u'PUNCT'),
#  (u'die', u'PRON'),
#  (u'vor', u'ADP'),
#  (u'allem', u'PRON'),
#  (u'in', u'ADP'),
#  (u'Belgrad', u'PROPN'),
#  (u'und', u'CONJ'),
#  (u'in', u'ADP'),
#  (u'der', u'DET'),
#  (u'nordserbischen', u'NOUN'),
#  (u'Wojwodina', u'PROPN'),
#  (u'an', u'ADP'),
#  (u'der', u'DET'),
#  (u'Grenze', u'NOUN'),
#  (u'zu', u'ADP'),
#  (u'Ungarn', u'PROPN'),
#  (u'umherirren', u'PROPN'),
#  (u'und', u'CONJ'),
#  (u'eine', u'DET'),
#  (u'Gelegenheit', u'NOUN'),
#  (u'zur', u'ADP'),
#  (u'illegalen', u'ADJ'),
#  (u'Weiterreise', u'NOUN'),
#  (u'suchen', u'VERB'),
#  (u'.', u'PUNCT'),
#  (u'Doch', u'CONJ'),
#  (u'die', u'DET'),
#  (u'Zahl', u'NOUN'),
#  (u'k\xf6nnte', u'AUX'),
#  (u'sich', u'PRON'),
#  (u'bald', u'ADV'),
#  (u'vervielfachen', u'PROPN'),
#  (u'.', u'PUNCT'),
#  (u'"', u'PUNCT'),
#  (u'Serbien', u'PROPN'),
#  (u'ist', u'VERB'),
#  (u'eingequetscht', u'PROPN'),
#  (u'zwischen', u'ADP'),
#  (u'Abschottung', u'NOUN'),
#  (u'im', u'DET'),
#  (u'Norden', u'NOUN'),
#  (u'und', u'CONJ'),
#  (u'dem', u'DET'),
#  (u'Strom', u'NOUN'),
#  (u'der', u'DET'),
#  (u'Fl\xfcchtlinge', u'NOUN'),
#  (u'von', u'ADP'),
#  (u'S\xfcden', u'PROPN'),
#  (u'"', u'PUNCT'),
#  (u',', u'PUNCT'),
#  (u'sagt', u'VERB'),
#  (u'Rados', u'PROPN'),
#  (u'Djurovic', u'PROPN'),
#  (u',', u'PUNCT'),
#  (u'der', u'DET'),
#  (u'Direktor', u'NOUN'),
#  (u'des', u'DET'),
#  (u'Belgrader', u'PROPN'),
#  (u'"', u'PUNCT'),
#  (u'Zentrums', u'PROPN'),
#  (u'zum', u'DET'),
#  (u'Schutz', u'NOUN'),
#  (u'f\xfcr', u'ADP'),
#  (u'Asylsuchende', u'NOUN'),
#  (u'"', u'PUNCT'),
#  (u'(', u'PUNCT'),
#  (u'CZA', u'PROPN'),
#  (u')', u'PUNCT'),
#  (u'.', u'PUNCT'),
#  (u'Und', u'CONJ'),
#  (u'die', u'DET'),
#  (u'Politologin', u'NOUN'),
#  (u'Jelena', u'PROPN'),
#  (u'Milic', u'PROPN'),
#  (u'vom', u'PROPN'),
#  (u'Belgrader', u'PROPN'),
#  (u'"', u'PUNCT'),
#  (u'Zentrum', u'PROPN'),
#  (u'f\xfcr', u'PROPN'),
#  (u'euro', u'PROPN'),
#  (u'-', u'PUNCT'),
#  (u'atlantische', u'ADJ'),
#  (u'Studien', u'NOUN'),
#  (u'"', u'PUNCT'),
#  (u'(', u'PUNCT'),
#  (u'CEAS', u'PROPN'),
#  (u')', u'PUNCT'),
#  (u'prognostiziert', u'VERB'),
#  (u'ein', u'DET'),
#  (u'"', u'PUNCT'),
#  (u'Desaster', u'NOUN'),
#  (u'f\xfcr', u'ADP'),
#  (u'Serbien', u'PROPN'),
#  (u',', u'PUNCT'),
#  (u'wenn', u'SCONJ'),
#  (u'\xd6sterreich', u'PROPN'),
#  (u',', u'PUNCT'),
#  (u'Slowenien', u'PROPN'),
#  (u'und', u'CONJ'),
#  (u'Kroatien', u'PROPN'),
#  (u'dichtmachen', u'VERB'),
#  (u'"', u'PUNCT'),
#  (u'.', u'PUNCT'),
#  (u'Serbien', u'PROPN'),
#  (u'ist', u'VERB'),
#  (u'bisher', u'ADV'),
#  (u',', u'PUNCT'),
#  (u'abgesehen', u'VERB'),
#  (u'von', u'ADP'),
#  (u'Griechenland', u'PROPN'),
#  (u',', u'PUNCT'),
#  (u'der', u'DET'),
#  (u'einzige', u'ADJ'),
#  (u'Staat', u'NOUN'),
#  (u'auf', u'ADP'),
#  (u'der', u'DET'),
#  (u'Balkanroute', u'PROPN'),
#  (u'f\xfcr', u'ADP'),
#  (u'Fl\xfcchtlinge', u'NOUN'),
#  (u',', u'PUNCT'),
#  (u'der', u'PRON'),
#  (u'noch', u'ADV'),
#  (u'keine', u'PRON'),
#  (u'Grenzz\xe4une', u'NOUN'),
#  (u'gebaut', u'VERB'),
#  (u'oder', u'CONJ'),
#  (u'seine', u'DET'),
#  (u'Grenze', u'NOUN'),
#  (u'nicht', u'PART'),
#  (u'zumindest', u'ADV'),
#  (u'mit', u'ADP'),
#  (u'Polizei', u'NOUN'),
#  (u'und', u'CONJ'),
#  (u'Milit\xe4r', u'NOUN'),
#  (u'stark', u'ADJ'),
#  (u'abgeschirmt', u'VERB'),
#  (u'hat', u'AUX'),
#  (u'.', u'PUNCT'),
#  (u'Das', u'PRON'),
#  (u'war', u'VERB'),
#  (u'ein', u'DET'),
#  (u'Kalk\xfcl', u'NOUN'),
#  (u'des', u'DET'),
#  (u'nationalistisch', u'ADJ'),
#  (u'-', u'PUNCT'),
#  (u'autorit\xe4ren', u'ADJ'),
#  (u'Regierungschefs', u'NOUN'),
#  (u'Vucic', u'PROPN'),
#  (u',', u'PUNCT'),
#  (u'der', u'PRON'),
#  (u'sich', u'PRON'),
#  (u'vor', u'ADP'),
#  (u'einigen', u'PRON'),
#  (u'Jahren', u'NOUN'),
#  (u'pl\xf6tzlich', u'ADV'),
#  (u'vom', u'DET'),
#  (u'\xfcberzeugten', u'ADJ'),
#  (u'Kriegshetzer', u'PROPN'),
#  (u'zum', u'DET'),
#  (u'vorgeblichen', u'ADJ'),
#  (u'Pro', u'NOUN'),
#  (u'-', u'PUNCT'),
#  (u'Europ\xe4er', u'NOUN'),
#  (u'wandelte', u'VERB'),
#  (u'und', u'CONJ'),
#  (u'der', u'PRON'),
#  (u'in', u'ADP'),
#  (u'der', u'DET'),
#  (u'Fl\xfcchtlingskrise', u'PROPN'),
#  (u'als', u'ADP'),
#  (u'einziger', u'ADJ'),
#  (u'Regierungschef', u'NOUN'),
#  (u'der', u'DET'),
#  (u'Region', u'NOUN'),
#  (u'explizit', u'ADJ'),
#  (u'immer', u'ADV'),
#  (u'wieder', u'ADV'),
#  (u'die', u'DET'),
#  (u'Linie', u'NOUN'),
#  (u'Angela', u'PROPN'),
#  (u'Merkels', u'PROPN'),
#  (u'unterst\xfctzte', u'VERB'),
#  (u'.', u'PUNCT'),
#  (u'Vucic', u'PROPN'),
#  (u'setzt', u'VERB'),
#  (u'auf', u'ADP'),
#  (u'Ann\xe4herung', u'NOUN'),
#  (u'Vucic', u'PROPN'),
#  (u'betonte', u'VERB'),
#  (u'wiederholt', u'ADJ'),
#  (u',', u'PUNCT'),
#  (u'Z\xe4une', u'NOUN'),
#  (u'und', u'CONJ'),
#  (u'Abschottung', u'NOUN'),
#  (u'seien', u'AUX'),
#  (u'keine', u'PRON'),
#  (u'L\xf6sung', u'NOUN'),
#  (u'-', u'PUNCT'),
#  (u'er', u'PRON'),
#  (u'hoffte', u'VERB'),
#  (u'darauf', u'ADV'),
#  (u',', u'PUNCT'),
#  (u'dass', u'SCONJ'),
#  (u'er', u'PRON'),
#  (u'mit', u'ADP'),
#  (u'dieser', u'PRON'),
#  (u'Linie', u'NOUN'),
#  (u'Serbiens', u'PROPN'),
#  (u'Ann\xe4hrung', u'PROPN'),
#  (u'an', u'ADP'),
#  (u'die', u'DET'),
#  (u'EU', u'PROPN'),
#  (u'beschleunigen', u'VERB'),
#  (u'k\xf6nnte', u'AUX'),
#  (u'und', u'CONJ'),
#  (u'dass', u'SCONJ'),
#  (u'westliche', u'ADJ'),
#  (u'Politiker', u'NOUN'),
#  (u'die', u'DET'),
#  (u'politischen', u'ADJ'),
#  (u'Verh\xe4ltnisse', u'NOUN'),
#  (u'in', u'ADP'),
#  (u'Serbien', u'PROPN'),
#  (u'weniger', u'ADV'),
#  (u'kritisch', u'ADJ'),
#  (u'be\xe4ugen', u'VERB'),
#  (u'w\xfcrden', u'AUX'),
#  (u':', u'PUNCT'),
#  (u'Ein', u'DET'),
#  (u'Gro\xdfteil', u'NOUN'),
#  (u'der', u'DET'),
#  (u'politischen', u'ADJ'),
#  (u'Elite', u'NOUN'),
#  (u'ist', u'VERB'),
#  (u'in', u'ADP'),
#  (u'Korruption', u'NOUN'),
#  (u'und', u'CONJ'),
#  (u'organisiertes', u'ADJ'),
#  (u'Verbrechen', u'NOUN'),
#  (u'verstrickt', u'VERB'),
#  (u',', u'PUNCT'),
#  (u'die', u'DET'),
#  (u'Justiz', u'NOUN'),
#  (u'vielfach', u'ADJ'),
#  (u'politisch', u'ADJ'),
#  (u'gelenkt', u'VERB'),
#  (u',', u'PUNCT'),
#  (u'es', u'PRON'),
#  (u'gibt', u'VERB'),
#  (u'nur', u'ADV'),
#  (u'wenige', u'PRON'),
#  (u'unabh\xe4ngige', u'ADJ'),
#  (u'Medien', u'NOUN'),
#  (u',', u'PUNCT'),
#  (u'und', u'CONJ'),
#  (u'unabh\xe4ngige', u'ADJ'),
#  (u'Journalisten', u'NOUN'),
#  (u'leben', u'VERB'),
#  (u'gef\xe4hrlich', u'ADJ'),
#  (u'.', u'PUNCT'),
#  (u'Zugleich', u'ADV'),
#  (u'ist', u'AUX'),
#  (u'Serbien', u'PROPN'),
#  (u'wegen', u'ADP'),
#  (u'der', u'DET'),
#  (u'prek\xe4ren', u'ADJ'),
#  (u'wirtschaftlichen', u'ADJ'),
#  (u'und', u'CONJ'),
#  (u'sozialen', u'ADJ'),
#  (u'Verh\xe4ltnisse', u'NOUN'),
#  (u'im', u'ADP'),
#  (u'Land', u'NOUN'),
#  (u'dringend', u'ADV'),
#  (u'auf', u'ADP'),
#  (u'eine', u'DET'),
#  (u'europ\xe4ische', u'ADJ'),
#  (u'Integration', u'NOUN'),
#  (u',', u'PUNCT'),
#  (u'auf', u'ADP'),
#  (u'Investitionen', u'NOUN'),
#  (u'und', u'CONJ'),
#  (u'auf', u'ADP'),
#  (u'finanzielle', u'ADJ'),
#  (u'Entwicklungshilfe', u'NOUN'),
#  (u'durch', u'ADP'),
#  (u'die', u'DET'),
#  (u'EU', u'PROPN'),
#  (u'angewiesen', u'VERB'),
#  (u'.', u'PUNCT'),
#  (u'Vucics', u'X'),
#  (u'Rechnung', u'NOUN'),
#  (u'schien', u'VERB'),
#  (u'aufzugehen', u'PROPN'),
#  (u'-', u'PUNCT'),
#  (u'Ende', u'NOUN'),
#  (u'letzten', u'ADJ'),
#  (u'Jahres', u'NOUN'),
#  (u'er\xf6ffneten', u'VERB'),
#  (u'die', u'DET'),
#  (u'EU', u'PROPN'),
#  (u'und', u'CONJ'),
#  (u'Serbien', u'PROPN'),
#  (u'die', u'DET'),
#  (u'ersten', u'ADJ'),
#  (u'beiden', u'PRON'),
#  (u'Kapitel', u'NOUN'),
#  (u'der', u'DET'),
#  (u'Beitrittsverhandlungen', u'NOUN'),
#  (u',', u'PUNCT'),
#  (u'weitere', u'ADJ'),
#  (u'sollen', u'AUX'),
#  (u'demn\xe4chst', u'ADV'),
#  (u'folgen', u'VERB'),
#  (u'.', u'PUNCT'),
#  (u'Doch', u'CONJ'),
#  (u'Jelena', u'PROPN'),
#  (u'Milic', u'PROPN'),
#  (u'sagt', u'VERB'),
#  (u',', u'PUNCT'),
#  (u'dass', u'SCONJ'),
#  (u'die', u'DET'),
#  (u'serbische', u'ADJ'),
#  (u'Fl\xfcchtlingspolitik', u'X'),
#  (u'sich', u'PRON'),
#  (u'als', u'ADP'),
#  (u'Falle', u'NOUN'),
#  (u'f\xfcr', u'ADP'),
#  (u'das', u'DET'),
#  (u'Land', u'NOUN'),
#  (u'erweisen', u'VERB'),
#  (u'k\xf6nnte', u'AUX'),
#  (u'.', u'PUNCT'),
#  (u'Denn', u'SCONJ'),
#  (u'die', u'DET'),
#  (u'Nachbarstaaten', u'NOUN'),
#  (u'schaffen', u'VERB'),
#  (u'weiter', u'ADJ'),
#  (u'Fakten', u'NOUN'),
#  (u':', u'PUNCT'),
#  (u'Ungarn', u'PROPN'),
#  (u'hat', u'VERB'),
#  (u'seine', u'DET'),
#  (u'Grenze', u'NOUN'),
#  (u'zu', u'ADP'),
#  (u'Serbien', u'PROPN'),
#  (u'bereits', u'ADV'),
#  (u'seit', u'ADP'),
#  (u'September', u'PROPN'),
#  (u'letzten', u'ADJ'),
#  (u'Jahres', u'NOUN'),
#  (u'vollst\xe4ndig', u'ADJ'),
#  (u'mit', u'ADP'),
#  (u'einem', u'DET'),
#  (u'Zaun', u'NOUN'),
#  (u'abgeriegelt', u'VERB'),
#  (u'.', u'PUNCT'),
#  (u'Seit', u'ADP'),
#  (u'Anfang', u'NOUN'),
#  (u'Januar', u'PROPN'),
#  (u'ist', u'VERB'),
#  (u'die', u'DET'),
#  (u'Zahl', u'NOUN'),
#  (u'der', u'DET'),
#  (u'illegalen', u'ADJ'),
#  (u'Grenz\xfcbertritte', u'NOUN'),
#  (u'aus', u'ADP'),
#  (u'Serbien', u'PROPN'),
#  (u'wieder', u'ADV'),
#  (u'deutlich', u'ADJ'),
#  (u'angestiegen', u'VERB'),
#  (u',', u'PUNCT'),
#  (u'deshalb', u'ADV'),
#  (u'verdoppelte', u'ADJ'),
#  (u'Ungarn', u'NOUN'),
#  (u'die', u'DET'),
#  (u'Zahl', u'NOUN'),
#  (u'der', u'DET'),
#  (u'Polizisten', u'NOUN'),
#  (u',', u'PUNCT'),
#  (u'die', u'PRON'),
#  (u'das', u'DET'),
#  (u'Grenzgebiet', u'NOUN'),
#  (u'bewachen', u'VERB'),
#  (u'.', u'PUNCT'),
#  (u'\xd6sterreich', u'PROPN'),
#  (u'hat', u'AUX'),
#  (u'mit', u'ADP'),
#  (u'seiner', u'DET'),
#  (u'zunehmend', u'ADJ'),
#  (u'restriktiveren', u'ADJ'),
#  (u'Fl\xfcchtlingspolitik', u'X'),
#  (u'auf', u'ADP'),
#  (u'der', u'DET'),
#  (u'Balkanroute', u'PROPN'),
#  (u'einen', u'DET'),
#  (u'Dominoeffekt', u'NOUN'),
#  (u'ausgel\xf6st', u'VERB'),
#  (u',', u'PUNCT'),
#  (u'jede', u'PRON'),
#  (u'neue', u'ADJ'),
#  (u'Beschr\xe4nkung', u'NOUN'),
#  (u'im', u'ADP'),
#  (u'Alpenland', u'NOUN'),
#  (u'wird', u'AUX'),
#  (u'nach', u'ADP'),
#  (u'S\xfcden', u'NOUN'),
#  (u'hin', u'ADV'),
#  (u'weitergegeben', u'VERB'),
#  (u';', u'PUNCT'),
#  (u'aktuell', u'ADV'),
#  (u'ist', u'VERB'),
#  (u'dies', u'PRON'),
#  (u'nach', u'ADP'),
#  (u'der', u'DET'),
#  (u'\xf6sterreichischen', u'ADJ'),
#  (u'Ank\xfcndigung', u'NOUN'),
#  (u',', u'PUNCT'),
#  (u'nur', u'ADV'),
#  (u'noch', u'ADV'),
#  (u'eine', u'DET'),
#  (u'stark', u'ADJ'),
#  (u'begrenzte', u'ADJ'),
#  (u'Anzahl', u'NOUN'),
#  (u'von', u'ADP'),
#  (u'Fl\xfcchtlingen', u'NOUN'),
#  (u'einreisen', u'VERB'),
#  (u'zu', u'PART'),
#  (u'lassen', u'VERB'),
#  (u',', u'PUNCT'),
#  (u'der', u'DET'),
#  (u'Fall', u'NOUN'),
#  (u'.', u'PUNCT'),
#  (u'Zugleich', u'ADV'),
#  (u'mit', u'ADP'),
#  (u'\xd6sterreich', u'PROPN'),
#  (u'baute', u'VERB'),
#  (u'auch', u'ADV'),
#  (u'Slowenien', u'PROPN'),
#  (u'Grenzz\xe4une', u'PROPN'),
#  (u'und', u'CONJ'),
#  (u'sicherte', u'VERB'),
#  (u'seine', u'DET'),
#  (u'Grenze', u'NOUN'),
#  (u'mit', u'ADP'),
#  (u'Sondertruppen', u'NOUN'),
#  (u'der', u'PROPN'),
#  (u'Polizei', u'PROPN'),
#  (u'und', u'CONJ'),
#  (u'der', u'DET'),
#  (u'Armee', u'NOUN'),
#  (u'.', u'PUNCT'),
#  (u'Kroatien', u'PROPN'),
#  (u'erw\xe4gt', u'VERB'),
#  (u'ebenfalls', u'ADV'),
#  (u'einen', u'DET'),
#  (u'Zaunbau', u'NOUN'),
#  (u'und', u'CONJ'),
#  (u'l\xe4sst', u'VERB'),
#  (u'seine', u'DET'),
#  (u'Grenze', u'NOUN'),
#  (u'zu', u'ADP'),
#  (u'Serbien', u'PROPN'),
#  (u'massiv', u'ADJ'),
#  (u'durch', u'ADP'),
#  (u'polizeiliche', u'ADJ'),
#  (u'Sondereinheiten', u'NOUN'),
#  (u'bewachen', u'VERB'),
#  (u'.', u'PUNCT'),
#  (u'Ein', u'DET'),
#  (u'Aufnahmelager', u'NOUN'),
#  (u'f\xfcr', u'ADP'),
#  (u'Fl\xfcchtlinge', u'NOUN'),
#  (u'im', u'PROPN'),
#  (u'ostkroatischen', u'PROPN'),
#  (u'Slavonski', u'PROPN'),
#  (u'Brod', u'PROPN'),
#  (u'soll', u'AUX'),
#  (u'geschlossen', u'ADJ'),
#  (u'werden', u'AUX'),
#  (u',', u'PUNCT'),
#  (u'Kroatien', u'PROPN'),
#  (u'will', u'AUX'),
#  (u'Fl\xfcchtlingen', u'NOUN'),
#  (u'nur', u'ADV'),
#  (u'noch', u'ADV'),
#  (u'einen', u'DET'),
#  (u'Non', u'PROPN'),
#  (u'-', u'PUNCT'),
#  (u'Stop', u'PROPN'),
#  (u'-', u'PUNCT'),
#  (u'Transit', u'NOUN'),
#  (u'durch', u'ADP'),
#  (u'das', u'DET'),
#  (u'Land', u'NOUN'),
#  (u'erlauben', u'VERB'),
#  (u'.', u'PUNCT'),
#  (u'Mazedonien', u'PROPN'),
#  (u'und', u'CONJ'),
#  (u'Bulgarien', u'PROPN'),
#  (u'sollen', u'AUX'),
#  (u'nach', u'ADP'),
#  (u'den', u'DET'),
#  (u'Vorstellungen', u'NOUN'),
#  (u'der', u'DET'),
#  (u'Visegr\xe1d', u'PROPN'),
#  (u'-', u'PUNCT'),
#  (u'L\xe4nder', u'NOUN'),
#  (u'Polen', u'PROPN'),
#  (u',', u'PUNCT'),
#  (u'Tschechien', u'PROPN'),
#  (u',', u'PUNCT'),
#  (u'Slowakei', u'PROPN'),
#  (u'und', u'CONJ'),
#  (u'Ungarn', u'PROPN'),
#  (u'sowie', u'CONJ'),
#  (u'\xd6sterreichs', u'PROPN'),
#  (u'und', u'CONJ'),
#  (u'Sloweniens', u'PROPN'),
#  (u'zu', u'ADP'),
#  (u'Frontstaaten', u'PROPN'),
#  (u'gegen', u'ADP'),
#  (u'Fl\xfcchtlinge', u'NOUN'),
#  (u'aufger\xfcstet', u'VERB'),
#  (u'werden', u'AUX'),
#  (u',', u'PUNCT'),
#  (u'falls', u'SCONJ'),
#  (u'Griechenland', u'PROPN'),
#  (u'den', u'DET'),
#  (u'Fl\xfcchtlingsstrom', u'NOUN'),
#  (u'nicht', u'PART'),
#  (u'stoppt', u'VERB'),
#  (u'.', u'PUNCT'),
#  (u'Beide', u'PRON'),
#  (u'L\xe4nder', u'NOUN'),
#  (u'bauen', u'VERB'),
#  (u'derzeit', u'ADV'),
#  (u'ihre', u'DET'),
#  (u'Grenzz\xe4une', u'NOUN'),
#  (u'zu', u'ADP'),
#  (u'Griechenland', u'PROPN'),
#  (u'und', u'CONJ'),
#  (u'der', u'DET'),
#  (u'T\xfcrkei', u'PROPN'),
#  (u'aus', u'ADP'),
#  (u';', u'PUNCT'),
#  (u'Mazedonien', u'PROPN'),
#  (u'l\xe4sst', u'AUX'),
#  (u'seit', u'ADP'),
#  (u'L\xe4ngerem', u'NOUN'),
#  (u'nur', u'ADV'),
#  (u'noch', u'ADV'),
#  (u'Fl\xfcchtlinge', u'NOUN'),
#  (u'aus', u'ADP'),
#  (u'Afghanistan', u'PROPN'),
#  (u',', u'PUNCT'),
#  (u'Irak', u'PROPN'),
#  (u'und', u'CONJ'),
#  (u'Syrien', u'PROPN'),
#  (u'mit', u'ADP'),
#  (u'g\xfcltigen', u'ADJ'),
#  (u'Papieren', u'NOUN'),
#  (u'durchreisen', u'PROPN'),
#  (u'.', u'PUNCT'),
#  (u'Mittendrin', u'PROPN'),
#  (u'liegt', u'VERB'),
#  (u'Serbien', u'PROPN'),
#  (u'-', u'PUNCT'),
#  (u'praktisch', u'ADV'),
#  (u'kaum', u'ADV'),
#  (u'gesch\xfctzt', u'ADJ'),
#  (u'.', u'PUNCT'),
#  (u'Erstmals', u'ADV'),
#  (u'wurde', u'AUX'),
#  (u'in', u'ADP'),
#  (u'dieser', u'PRON'),
#  (u'Woche', u'NOUN'),
#  (u'eine', u'DET'),
#  (u'gr\xf6\xdfere', u'ADJ'),
#  (u'Gruppe', u'NOUN'),
#  (u'von', u'ADP'),
#  (u'Fl\xfcchtlingen', u'NOUN'),
#  (u'durch', u'ADP'),
#  (u'mehrere', u'PRON'),
#  (u'L\xe4nder', u'NOUN'),
#  (u'der', u'DET'),
#  (u'Balkanroute', u'PROPN'),
#  (u'nach', u'ADP'),
#  (u'Serbien', u'PROPN'),
#  (u'zur\xfcckgereicht', u'PROPN'),
#  (u':', u'PUNCT'),
#  (u'217', u'NUM'),
#  (u'Menschen', u'NOUN'),
#  (u',', u'PUNCT'),
#  (u'die', u'DET'),
#  (u'meisten', u'NOUN'),
#  (u'von', u'ADP'),
#  (u'ihnen', u'PRON'),
#  (u'Afghanen', u'NOUN'),
#  (u',', u'PUNCT'),
#  (u'wurden', u'AUX'),
#  (u'von', u'ADP'),
#  (u'Slowenien', u'PROPN'),
#  (u'nach', u'ADP'),
#  (u'Kroatien', u'PROPN'),
#  (u'und', u'CONJ'),
#  (u'von', u'ADP'),
#  (u'dort', u'ADV'),
#  (u'aus', u'ADP'),
#  (u'wiederum', u'ADV'),
#  (u'nach', u'ADP'),
#  (u'Serbien', u'PROPN'),
#  (u'abgeschoben', u'VERB'),
#  (u'.', u'PUNCT'),
#  (u'Serbische', u'PROPN'),
#  (u'Beh\xf6rden', u'NOUN'),
#  (u'sind', u'VERB'),
#  (u'ratlos', u'ADJ'),
#  (u',', u'PUNCT'),
#  (u'was', u'PRON'),
#  (u'sie', u'PRON'),
#  (u'mit', u'ADP'),
#  (u'ihnen', u'PRON'),
#  (u'machen', u'VERB'),
#  (u'sollen', u'AUX'),
#  (u'-', u'PUNCT'),
#  (u'Mazedonien', u'PROPN'),
#  (u'will', u'AUX'),
#  (u'sie', u'PRON'),
#  (u'vorerst', u'ADV'),
#  (u'nicht', u'PART'),
#  (u'zur\xfccknehmen', u'VERB'),
#  (u',', u'PUNCT'),
#  (u'vermutlich', u'ADV'),
#  (u'w\xfcrden', u'AUX'),
#  (u'sie', u'PRON'),
#  (u'irgendwann', u'ADV'),
#  (u'in', u'ADP'),
#  (u'ihre', u'DET'),
#  (u'Herkunftsl\xe4nder', u'NOUN'),
#  (u'ausgeflogen', u'VERB'),
#  (u',', u'PUNCT'),
#  (u'sagt', u'VERB'),
#  (u'die', u'DET'),
#  (u'Sprecherin', u'NOUN'),
#  (u'des', u'DET'),
#  (u'Innenministeriums', u'NOUN'),
#  (u',', u'PUNCT'),
#  (u'Biljana', u'PROPN'),
#  (u'Popovic', u'PROPN'),
#  (u'.', u'PROPN'),
#  (u'Neuer', u'PROPN'),
#  (u'Markt', u'NOUN'),
#  (u'f\xfcr', u'ADP'),
#  (u'Schlepper', u'NOUN'),
#  (u'Die', u'PROPN'),
#  (u'Abschottungspolitik', u'NOUN'),
#  (u'in', u'ADP'),
#  (u'Serbiens', u'PROPN'),
#  (u'Nachbarl\xe4ndern', u'NOUN'),
#  (u'hat', u'AUX'),
#  (u'auch', u'ADV'),
#  (u'zur', u'ADP'),
#  (u'Folge', u'NOUN'),
#  (u',', u'PUNCT'),
#  (u'dass', u'SCONJ'),
#  (u'immer', u'ADV'),
#  (u'mehr', u'ADV'),
#  (u'kriminelle', u'ADJ'),
#  (u'Schlepper', u'NOUN'),
#  (u'in', u'ADP'),
#  (u'serbischen', u'ADJ'),
#  (u'Grenzgebieten', u'NOUN'),
#  (u'aktiv', u'ADJ'),
#  (u'sind', u'VERB'),
#  (u',', u'PUNCT'),
#  (u'wie', u'ADP'),
#  (u'Rados', u'PROPN'),
#  (u'Djurovic', u'X'),
#  (u'vom', u'DET'),
#  (u'"', u'PUNCT'),
#  (u'Zentrum', u'NOUN'),
#  (u'zum', u'DET'),
#  (u'Schutz', u'NOUN'),
#  (u'f\xfcr', u'ADP'),
#  (u'Asylsuchende', u'NOUN'),
#  (u'"', u'PUNCT'),
#  (u'sagt', u'VERB'),
#  (u'.', u'PUNCT'),
#  (u'"', u'PUNCT'),
#  (u'Die', u'PROPN'),
#  (u'Leute', u'NOUN'),
#  (u',', u'PUNCT'),
#  (u'die', u'PRON'),
#  (u'nicht', u'PART'),
#  (u'mehr', u'ADV'),
#  (u'durchgelassen', u'NOUN'),
#  (u'werden', u'AUX'),
#  (u',', u'PUNCT'),
#  (u'sind', u'VERB'),
#  (u'die', u'DET'),
#  (u'perfekte', u'ADJ'),
#  (u'Beute', u'NOUN'),
#  (u'f\xfcr', u'ADP'),
#  (u'Schlepper', u'NOUN'),
#  (u'"', u'PUNCT'),
#  (u',', u'PUNCT'),
#  (u'so', u'ADV'),
#  (u'Djurovic', u'NOUN'),
#  (u'.', u'PUNCT'),
#  (u'Vor', u'ADP'),
#  (u'allem', u'PRON'),
#  (u'an', u'ADP'),
#  (u'der', u'DET'),
#  (u'Grenze', u'NOUN'),
#  (u'zu', u'ADP'),
#  (u'Mazedonien', u'PROPN'),
#  (u'und', u'CONJ'),
#  (u'zu', u'ADP'),
#  (u'Ungarn', u'PROPN'),
#  (u'bl\xfche', u'X'),
#  (u'das', u'DET'),
#  (u'Schlepperunwesen', u'NOUN'),
#  (u'momentan', u'ADJ'),
#  (u'wieder', u'ADV'),
#  (u'auf', u'ADP'),
#  (u'.', u'PUNCT'),
#  (u'Noch', u'ADV'),
#  (u'ist', u'VERB'),
#  (u'unklar', u'ADJ'),
#  (u',', u'PUNCT'),
#  (u'wann', u'ADV'),
#  (u'und', u'CONJ'),
#  (u'wie', u'ADP'),
#  (u'Serbien', u'PROPN'),
#  (u'seine', u'DET'),
#  (u'Fl\xfcchtlingspolitik', u'NOUN'),
#  (u'\xe4ndern', u'VERB'),
#  (u'wird', u'AUX'),
#  (u'.', u'PUNCT'),
#  (u'Das', u'DET'),
#  (u'Land', u'NOUN'),
#  (u'ist', u'VERB'),
#  (u'besonders', u'ADV'),
#  (u'wegen', u'ADP'),
#  (u'Kosovo', u'PROPN'),
#  (u'in', u'ADP'),
#  (u'einer', u'DET'),
#  (u'schwierige', u'ADJ'),
#  (u'Lage', u'NOUN'),
#  (u':', u'PUNCT'),
#  (u'Selbst', u'ADV'),
#  (u'wenn', u'SCONJ'),
#  (u'es', u'PRON'),
#  (u'seine', u'DET'),
#  (u'Grenzen', u'NOUN'),
#  (u'zu', u'ADP'),
#  (u'Bulgarien', u'PROPN'),
#  (u'und', u'CONJ'),
#  (u'Mazedonien', u'PROPN'),
#  (u'schlie\xdft', u'VERB'),
#  (u',', u'PUNCT'),
#  (u'bliebe', u'VERB'),
#  (u'die', u'PRON'),
#  (u'zu', u'ADP'),
#  (u'Kosovo', u'PROPN'),
#  (u'offen', u'ADJ'),
#  (u',', u'PUNCT'),
#  (u'da', u'SCONJ'),
#  (u'Serbien', u'PROPN'),
#  (u'das', u'DET'),
#  (u'Land', u'NOUN'),
#  (u'nicht', u'PART'),
#  (u'anerkennt', u'VERB'),
#  (u',', u'PUNCT'),
#  (u'sondern', u'CONJ'),
#  (u'als', u'ADP'),
#  (u'abtr\xfcnnige', u'PROPN'),
#  (u'Provinz', u'NOUN'),
#  (u'betrachtet', u'VERB'),
#  (u'.', u'PUNCT'),
#  (u'Doch', u'CONJ'),
#  (u'dass', u'SCONJ'),
#  (u'bald', u'ADV'),
#  (u'eine', u'DET'),
#  (u'\xc4nderung', u'NOUN'),
#  (u'in', u'ADP'),
#  (u'der', u'DET'),
#  (u'Fl\xfcchtlingspolitik', u'NOUN'),
#  (u'anstehen', u'VERB'),
#  (u'k\xf6nnte', u'AUX'),
#  (u',', u'PUNCT'),
#  (u'daran', u'ADV'),
#  (u'l\xe4sst', u'VERB'),
#  (u'die', u'DET'),
#  (u'serbische', u'ADJ'),
#  (u'Regierung', u'NOUN'),
#  (u'keinen', u'PRON'),
#  (u'Zweifel', u'NOUN'),
#  (u'.', u'PUNCT'),
#  (u'"', u'PUNCT'),
#  (u'Ich', u'PRON'),
#  (u'bin', u'VERB'),
#  (u'kein', u'PRON'),
#  (u'Freund', u'NOUN'),
#  (u'von', u'ADP'),
#  (u'Mauern', u'NOUN'),
#  (u'"', u'PUNCT'),
#  (u',', u'PUNCT'),
#  (u'sagte', u'VERB'),
#  (u'Regierungschef', u'NOUN'),
#  (u'Aleksandar', u'PROPN'),
#  (u'Vucic', u'PROPN'),
#  (u'k\xfcrzlich', u'ADJ'),
#  (u',', u'PUNCT'),
#  (u'"', u'PUNCT'),
#  (u'aber', u'CONJ'),
#  (u'wir', u'PRON'),
#  (u'm\xfcssen', u'AUX'),
#  (u'unsere', u'PRON'),
#  (u'Grenzen', u'NOUN'),
#  (u'sch\xfctzen', u'VERB'),
#  (u'.', u'PUNCT'),
#  (u'"', u'PUNCT'),
#  (u'Sein', u'DET'),
#  (u'Au\xdfenminister', u'NOUN'),
#  (u'Ivica', u'PROPN'),
#  (u'Dacic', u'PROPN'),
#  (u'ging', u'VERB'),
#  (u'dieser', u'PRON'),
#  (u'Tage', u'NOUN'),
#  (u'noch', u'ADV'),
#  (u'weiter', u'ADV'),
#  (u':', u'PUNCT'),
#  (u'"', u'PUNCT'),
#  (u'Wir', u'PRON'),
#  (u'werden', u'AUX'),
#  (u'es', u'PRON'),
#  (u'nicht', u'PART'),
#  (u'zulassen', u'VERB'),
#  (u',', u'PUNCT'),
#  (u'dass', u'SCONJ'),
#  (u'die', u'DET'),
#  (u'Fl\xfcchtlinge', u'NOUN'),
#  ...]

# %% [markdown]
# ## Named Entity Recognition (Locations, Organizations, Persons)

# %%
from polyglot.downloader import downloader
print(downloader.supported_languages_table("ner2", 3))
# Out:
#   1. Polish                     2. Turkish                    3. Indonesian
#   4. Thai                       5. Czech                      6. Arabic
#   7. Korean                     8. Catalan; Valencian         9. Italian
#  10. Malay                     11. Romanian, Moldavian, ...  12. Tagalog
#  13. Danish                    14. Finnish                   15. German
#  16. Persian                   17. Latvian                   18. Chinese
#  19. French                    20. Portuguese                21. Hebrew (modern)
#  22. Slovak                    23. Slovene                   24. Bulgarian
#  25. Hindi                     26. Japanese                  27. Hungarian
#  28. Croatian                  29. Ukrainian                 30. Serbian
#  31. Lithuanian                32. Norwegian                 33. Dutch
#  34. Swedish                   35. Russian                   36. English
#  37. Greek, Modern             38. Spanish; Castilian        39. Vietnamese
#  40. Estonian

# %% [markdown]
# ## English

# %%
# %%bash
# polyglot download embeddings2.en ner2.en
# Out:
# [polyglot_data] Downloading package embeddings2.en to
# [polyglot_data]     /home/pgross/polyglot_data...
# [polyglot_data]   Package embeddings2.en is already up-to-date!
# [polyglot_data] Downloading package ner2.en to
# [polyglot_data]     /home/pgross/polyglot_data...
# [polyglot_data]   Package ner2.en is already up-to-date!

# %%
text_en.entities
# Out:
# [I-ORG([u'Police']),
#  I-PER([u'George', u'Gaynes']),
#  I-ORG([u'Entertainment']),
#  I-ORG([u'Arts']),
#  I-PER([u'Arts', u'George', u'GaynesImage']),
#  I-PER([u'George', u'Gaynes']),
#  I-PER([u'George', u'Gaynes']),
#  I-PER([u'Gaynes']),
#  I-ORG([u'Police', u'Academy']),
#  I-PER([u'Punky', u'Brewster']),
#  I-PER([u'Dustin', u'Hoffman']),
#  I-PER([u'Oscar']),
#  I-PER([u'Jonathan', u'Howard']),
#  I-ORG([u'Hollywood', u'Reporter'])]

# %% [markdown]
# ## German

# %%
# %%bash
# polyglot download embeddings2.en ner2.de
# Out:
# [polyglot_data] Downloading package embeddings2.en to
# [polyglot_data]     /home/pgross/polyglot_data...
# [polyglot_data]   Package embeddings2.en is already up-to-date!
# [polyglot_data] Downloading package ner2.de to
# [polyglot_data]     /home/pgross/polyglot_data...
# [polyglot_data]   Package ner2.de is already up-to-date!

# %%
text_de.entities
# Out:
# [I-LOC([u'Serbien']),
#  I-LOC([u'schotten']),
#  I-LOC([u'Serbien']),
#  I-LOC([u'Serbien']),
#  I-LOC([u'Belgrad']),
#  I-PER([u'Aleksandar', u'Vucic']),
#  I-LOC([u'Serbien']),
#  I-PER([u'weiterziehen']),
#  I-LOC([u'Belgrad']),
#  I-LOC([u'Ungarn']),
#  I-PER([u'Ungarn', u'umherirren']),
#  I-LOC([u'Serbien']),
#  I-PER([u'Djurovic']),
#  I-ORG([u'Belgrader']),
#  I-PER([u'Jelena', u'Milic']),
#  I-LOC([u'Serbien']),
#  I-LOC([u'\xd6sterreich']),
#  I-LOC([u'Slowenien']),
#  I-LOC([u'Kroatien']),
#  I-LOC([u'Serbien']),
#  I-LOC([u'Griechenland']),
#  I-ORG([u'Vucic']),
#  I-PER([u'Kriegshetzer']),
#  I-PER([u'Angela', u'Merkels']),
#  I-PER([u'Vucic']),
#  I-PER([u'Vucic']),
#  I-ORG([u'EU']),
#  I-LOC([u'Serbien']),
#  I-LOC([u'Serbien']),
#  I-ORG([u'EU']),
#  I-PER([u'aufzugehen']),
#  I-ORG([u'EU']),
#  I-LOC([u'Serbien']),
#  I-PER([u'Jelena', u'Milic']),
#  I-LOC([u'Serbien']),
#  I-LOC([u'Serbien']),
#  I-LOC([u'Ungarn']),
#  I-LOC([u'\xd6sterreich']),
#  I-LOC([u'\xd6sterreich']),
#  I-LOC([u'Slowenien']),
#  I-LOC([u'Sondertruppen']),
#  I-ORG([u'Polizei']),
#  I-ORG([u'Armee']),
#  I-ORG([u'Kroatien']),
#  I-LOC([u'Serbien']),
#  I-LOC([u'Kroatien']),
#  I-LOC([u'Mazedonien']),
#  I-LOC([u'Bulgarien']),
#  I-LOC([u'Polen']),
#  I-LOC([u'Tschechien']),
#  I-LOC([u'Slowakei']),
#  I-LOC([u'Ungarn']),
#  I-LOC([u'Frontstaaten']),
#  I-LOC([u'Griechenland']),
#  I-LOC([u'Griechenland']),
#  I-LOC([u'T\xfcrkei']),
#  I-LOC([u'Mazedonien']),
#  I-LOC([u'Afghanistan']),
#  I-LOC([u'Irak']),
#  I-LOC([u'Syrien']),
#  I-LOC([u'Serbien']),
#  I-LOC([u'Serbien']),
#  I-LOC([u'Slowenien']),
#  I-LOC([u'Kroatien']),
#  I-LOC([u'Serbien']),
#  I-ORG([u'Serbische']),
#  I-LOC([u'Mazedonien']),
#  I-PER([u'Biljana', u'Popovic']),
#  I-PER([u'Rados', u'Djurovic']),
#  I-LOC([u'Mazedonien']),
#  I-LOC([u'Ungarn']),
#  I-PER([u'Ungarn', u'bl\xfche']),
#  I-LOC([u'Serbien']),
#  I-LOC([u'Kosovo']),
#  I-LOC([u'Bulgarien']),
#  I-LOC([u'Mazedonien']),
#  I-LOC([u'Kosovo']),
#  I-LOC([u'Serbien']),
#  I-LOC([u'serbische']),
#  I-PER([u'Aleksandar', u'Vucic']),
#  I-PER([u'Ivica', u'Dacic']),
#  I-LOC([u'Serbien']),
#  I-PER([u'stranden']),
#  I-LOC([u'Serbien'])]

# %% [markdown]
# ## Highlight annotations

# %%
from jinja2 import Template

# %%
def find_all_char_offsets(text, tokens):
    """Helper method for reconstructing the character ranges of a text that is split into tokens"""
    i = 0
    start_offsets, end_offsets = [], []
    for token in tokens:
        i = text.find(token, i)
        start_offsets.append(i)
        end_offsets.append(i+len(token))
    return start_offsets, end_offsets

def transform_to_annotations(text):
    "Extract the sentence and entity annotations from a text"
    for sent in text.sentences:
        rel_start_offsets, rel_end_offsets = find_all_char_offsets(text.raw[sent.start:sent.end], sent.words)
        for j, chunk in enumerate(sent.entities):
            char_start = sent.start + rel_start_offsets[chunk.start]
            char_end = sent.start + rel_end_offsets[chunk.end-1]
            entity_substring = text[char_start:char_end]
            yield dict(type='Entity',
                       char_start=char_start,
                       char_end=char_end,
                       entity_tag=chunk.tag,
                       text=text.raw[char_start:char_end])


def add_missing_char_segments(text, annotations, default_type="Plaintext"):
    """Given a strictly orderer list of annotations without overlaps, the missing ranges with a specified
    default annotation type are inserted, so that the resulting sequence of annotations is contiguous"""
    lines = []
    last_offset = 0
    for anno in annotations:
        char_start = anno['char_start']
        char_end = anno['char_end']
        if last_offset < char_start:
            yield dict(type=default_type,
                       char_start=last_offset,
                       char_end=char_start,
                       text=text.raw[last_offset:char_start])
        yield anno
        last_offset = char_end
    if last_offset < len(text):
        yield dict(type=default_type,
                    char_start=last_offset,
                    char_end=len(text),
                    text=text.raw[last_offset:])
        
def render_segments_to_html(segments):
    t = Template("""
    <html>
    <head>
    <style>
    .I-PER { box-shadow: 0px 3px 0px 0px #99ff66;}
    .I-LOC { box-shadow: 0px 3px 0px 0px #6699ff;}
    .I-ORG { box-shadow: 0px 3px 0px 0px #ff6600;}
    </style>    
    </head>
    <body>
    <p>
    Entites: <span class="I-PER">Person</span>, <span class="I-ORG">Organisation</span>, <span class="I-LOC">Location</span>
    </p>
    <p>
    {% for vm in segments %}<span class="{{vm.get('entity_tag','')}}">{{ vm['text'] }}</span>{% endfor %}
    </p>
    </body>
    </html>""")     
    return t.render(segments=segments)

def highlight_entities(text):
    entity_annos = transform_to_annotations(text)
    segments = [anno for anno in add_missing_char_segments(text, entity_annos)]
    html = render_segments_to_html(segments)
    return html

# %%
from IPython.core.display import HTML
HTML(highlight_entities(text_de))
# Out:
#     <html>
#     <head>
#     <style>
#     .I-PER { box-shadow: 0px 3px 0px 0px #99ff66;}
#     .I-LOC { box-shadow: 0px 3px 0px 0px #6699ff;}
#     .I-ORG { box-shadow: 0px 3px 0px 0px #ff6600;}
#     </style>
#     </head>
#     <body>
#     <p>
#     Entites: <span class="I-PER">Person</span>, <span class="I-ORG">Organisation</span>, <span class="I-LOC">Location</span>
#     </p>
#     <p>
#     <span class="">
# Flüchtlinge in </span><span class="I-LOC">Serbien</span><span class="">
#
# Das letzte Land ohne Zäune
# Von </span><span class="I-PER">Keno</span><span class=""> Verseck
#
# Die Nachbarländer </span><span class="I-LOC">schotten</span><span class=""> ihre Grenzen ab, nun landen in </span><span class="I-LOC">Serbien</span><span class=""> immer mehr Flüchtlinge. Die bisherige, freizügige Politik erweist sich als Falle für das Land. Gleichzeitig boomt das Geschäft der Schlepper.
#
# </span><span class="I-LOC">Serbien</span><span class=""> dürfe kein "Parkplatz für Flüchtlinge" werden, kein "Sammellager für Migranten auf dem Balkan" - solche drastischen Worte sind derzeit in </span><span class="I-LOC">Belgrad</span><span class=""> vom serbischen Regierungschef </span><span class="I-PER">Aleksandar Vucic</span><span class=""> oder von Mitgliedern seines Kabinetts immer öfter zu hören.
#
# Aus gutem Grund, denn in </span><span class="I-LOC">Serbien</span><span class=""> könnte genau das eintreten, wovor die Regierung warnt: Im größten Land des Westbalkans stranden immer mehr Flüchtlinge - sie sind von Süden her legal oder illegal eingereist, wollen </span><span class="I-PER">weiterziehen</span><span class=""> nach Westeuropa, stoßen aber im Norden auf abgesperrte Grenzen oder werden aus den Nachbarländern abgeschoben.
#
# Noch geht es nach Schätzungen von Beobachtern nur um höchstens einige Tausend Menschen, die vor allem in </span><span class="I-LOC">Belgrad</span><span class=""> und in der nordserbischen Wojwodina an der Grenze zu </span><span class="I-LOC">Ungarn</span><span class="I-PER">Ungarn umherirren</span><span class=""> und eine Gelegenheit zur illegalen Weiterreise suchen. Doch die Zahl könnte sich bald vervielfachen.
#
# "</span><span class="I-LOC">Serbien</span><span class=""> ist eingequetscht zwischen Abschottung im Norden und dem Strom der Flüchtlinge von Süden", sagt Rados </span><span class="I-PER">Djurovic</span><span class="">, der Direktor des </span><span class="I-ORG">Belgrader</span><span class=""> "Zentrums zum Schutz für Asylsuchende" (CZA). Und die Politologin </span><span class="I-PER">Jelena Milic</span><span class=""> vom Belgrader "Zentrum für euro-atlantische Studien" (CEAS) prognostiziert ein "Desaster für </span><span class="I-LOC">Serbien</span><span class="">, wenn </span><span class="I-LOC">Österreich</span><span class="">, </span><span class="I-LOC">Slowenien</span><span class=""> und </span><span class="I-LOC">Kroatien</span><span class=""> dichtmachen".
#
# </span><span class="I-LOC">Serbien</span><span class=""> ist bisher, abgesehen von </span><span class="I-LOC">Griechenland</span><span class="">, der einzige Staat auf der Balkanroute für Flüchtlinge, der noch keine Grenzzäune gebaut oder seine Grenze nicht zumindest mit Polizei und Militär stark abgeschirmt hat.
#
# Das war ein Kalkül des nationalistisch-autoritären Regierungschefs </span><span class="I-ORG">Vucic</span><span class="">, der sich vor einigen Jahren plötzlich vom überzeugten </span><span class="I-PER">Kriegshetzer</span><span class=""> zum vorgeblichen Pro-Europäer wandelte und der in der Flüchtlingskrise als einziger Regierungschef der Region explizit immer wieder die Linie </span><span class="I-PER">Angela Merkels</span><span class=""> unterstützte.
#
# </span><span class="I-PER">Vucic</span><span class=""> setzt auf Annäherung
#
# </span><span class="I-PER">Vucic</span><span class=""> betonte wiederholt, Zäune und Abschottung seien keine Lösung - er hoffte darauf, dass er mit dieser Linie Serbiens Annährung an die </span><span class="I-ORG">EU</span><span class=""> beschleunigen könnte und dass westliche Politiker die politischen Verhältnisse in </span><span class="I-LOC">Serbien</span><span class=""> weniger kritisch beäugen würden: Ein Großteil der politischen Elite ist in Korruption und organisiertes Verbrechen verstrickt, die Justiz vielfach politisch gelenkt, es gibt nur wenige unabhängige Medien, und unabhängige Journalisten leben gefährlich.
#
# Zugleich ist </span><span class="I-LOC">Serbien</span><span class=""> wegen der prekären wirtschaftlichen und sozialen Verhältnisse im Land dringend auf eine europäische Integration, auf Investitionen und auf finanzielle Entwicklungshilfe durch die </span><span class="I-ORG">EU</span><span class=""> angewiesen.
#
# Vucics Rechnung schien </span><span class="I-PER">aufzugehen</span><span class=""> - Ende letzten Jahres eröffneten die </span><span class="I-ORG">EU</span><span class=""> und </span><span class="I-LOC">Serbien</span><span class=""> die ersten beiden Kapitel der Beitrittsverhandlungen, weitere sollen demnächst folgen. Doch </span><span class="I-PER">Jelena Milic</span><span class=""> sagt, dass die serbische Flüchtlingspolitik sich als Falle für das Land erweisen könnte. Denn die Nachbarstaaten schaffen weiter Fakten:
#
# </span><span class="I-LOC">Ungarn</span><span class=""> hat seine Grenze zu </span><span class="I-LOC">Serbien</span><span class=""> bereits seit September letzten Jahres vollständig mit einem Zaun abgeriegelt. Seit Anfang Januar ist die Zahl der illegalen Grenzübertritte aus </span><span class="I-LOC">Serbien</span><span class=""> wieder deutlich angestiegen, deshalb verdoppelte </span><span class="I-LOC">Ungarn</span><span class=""> die Zahl der Polizisten, die das Grenzgebiet bewachen.
# </span><span class="I-LOC">Österreich</span><span class=""> hat mit seiner zunehmend restriktiveren Flüchtlingspolitik auf der Balkanroute einen Dominoeffekt ausgelöst, jede neue Beschränkung im Alpenland wird nach Süden hin weitergegeben; aktuell ist dies nach der österreichischen Ankündigung, nur noch eine stark begrenzte Anzahl von Flüchtlingen einreisen zu lassen, der Fall.
# Zugleich mit </span><span class="I-LOC">Österreich</span><span class=""> baute auch </span><span class="I-LOC">Slowenien</span><span class=""> Grenzzäune und sicherte seine Grenze mit </span><span class="I-LOC">Sondertruppen</span><span class=""> der </span><span class="I-ORG">Polizei</span><span class=""> und der </span><span class="I-ORG">Armee</span><span class="">.
# </span><span class="I-LOC">Kroatien</span><span class=""> erwägt ebenfalls einen Zaunbau und lässt seine Grenze zu </span><span class="I-LOC">Serbien</span><span class=""> massiv durch polizeiliche Sondereinheiten bewachen. Ein Aufnahmelager für Flüchtlinge im ostkroatischen Slavonski Brod soll geschlossen werden, </span><span class="I-LOC">Kroatien</span><span class=""> will Flüchtlingen nur noch einen Non-Stop-Transit durch das Land erlauben.
# </span><span class="I-LOC">Mazedonien</span><span class=""> und </span><span class="I-LOC">Bulgarien</span><span class=""> sollen nach den Vorstellungen der Visegrád-Länder </span><span class="I-LOC">Polen</span><span class="">, </span><span class="I-LOC">Tschechien</span><span class="">, </span><span class="I-LOC">Slowakei</span><span class=""> und </span><span class="I-LOC">Ungarn</span><span class=""> sowie Österreichs und Sloweniens zu </span><span class="I-LOC">Frontstaaten</span><span class=""> gegen Flüchtlinge aufgerüstet werden, falls </span><span class="I-LOC">Griechenland</span><span class=""> den Flüchtlingsstrom nicht stoppt. Beide Länder bauen derzeit ihre Grenzzäune zu </span><span class="I-LOC">Griechenland</span><span class=""> und der </span><span class="I-LOC">Türkei</span><span class=""> aus; </span><span class="I-LOC">Mazedonien</span><span class=""> lässt seit Längerem nur noch Flüchtlinge aus </span><span class="I-LOC">Afghanistan</span><span class="">, </span><span class="I-LOC">Irak</span><span class=""> und </span><span class="
